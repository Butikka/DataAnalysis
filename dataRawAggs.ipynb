# %%
import requests
import pandas as pd
# from datetime import datetime, timedelta, date
import datetime
import time
from polygon import RESTClient
import logging
import signal
import sys
import pickle
import lz4.frame  # type: ignore
import concurrent.futures
import os

# %%
# Define the API details
api_key = 'PfZz8S38d1PO4heiApoM7SGLFohMi3KE'

# Set up logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(message)s")

# Define the path where the files will be saved
save_path = "C:\\Users\\SamuliMustonen\\Documents\\Ready Solutions\\Docs\\StockTrading\\Data\\rawAggs"

# Create the directory if it doesn't exist
os.makedirs(save_path, exist_ok=True)

# Signal handler for graceful shutdown
def signal_handler(sig, frame):
    print("You pressed Ctrl+C!")
    sys.exit(0)

signal.signal(signal.SIGINT, signal_handler)

# Function to retrieve and save aggregate data for a given ticker over a date range
def get_aggs_for_ticker(ticker, start_date, end_date):
    """Retrieve aggregates for a given ticker and date range"""
    client = RESTClient(api_key=api_key)  # Initialize client

    aggs = []
    for day in weekdays_between(start_date, end_date):
        for a in client.list_aggs(ticker, 1, "day", day, day, limit=50000):
            aggs.append(a)

    # Save the data to a compressed .pickle.lz4 file
    filename = os.path.join(save_path, f"{ticker}-aggs-{start_date}_to_{end_date}.pickle.lz4")
    with open(filename, "wb") as file:
        try:
            compressed_data = lz4.frame.compress(pickle.dumps(aggs))
            file.write(compressed_data)
        except TypeError as e:
            logging.error(f"Serialization Error for {ticker}: {e}")

    logging.info(f"Downloaded aggs for {ticker} from {start_date} to {end_date} and saved to {filename}")

# Function to generate all weekdays between two dates
def weekdays_between(start_date, end_date):
    """Generate all weekdays between start_date and end_date"""
    day = start_date
    while day <= end_date:
        if day.weekday() < 5:  # Only Monday to Friday
            yield day
        day += timedelta(days=1)

def main():
    start_date = datetime.date(2022, 1, 1)  # Start date: Beginning of 2022
    end_date = datetime.date(2024, 9, 30)   # End date: 2024-09-30

    # Load tickers from CSV file (assumes the CSV file has columns 'Ticker' and 'Market-Cap')
    csv_file_path = "C:\\Users\\SamuliMustonen\\Documents\\Ready Solutions\\Docs\\StockTrading\\Data\\Tickers\\tickers_500m_to_10b.csv"  # Update this path with your actual file location
    df_tickers = pd.read_csv(csv_file_path, delimiter=',', header=0)

    # Extract tickers from the 'Ticker' column
    symbols = df_tickers['Ticker'].tolist()

    # Use ThreadPoolExecutor to download data for each ticker in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(get_aggs_for_ticker, symbol, start_date, end_date) for symbol in symbols]
        
        # Optional: to make sure each task completes
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  # This will raise any exceptions that occurred during execution
            except Exception as e:
                logging.error(f"Error fetching data: {e}")

if __name__ == "__main__":
    main()
# Out:
# 2024-10-18 15:17:45,320 - Downloaded aggs for AACT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AACT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:46,969 - Downloaded aggs for ABCL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ABCL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:47,053 - Downloaded aggs for ABUS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ABUS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:47,319 - Downloaded aggs for ABL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ABL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:47,469 - Downloaded aggs for AAOI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AAOI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:48,119 - Downloaded aggs for ABVX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ABVX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:48,803 - Downloaded aggs for AAT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AAT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:48,853 - Downloaded aggs for AC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:48,986 - Downloaded aggs for ACCO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ACCO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:17:49,002 - Downloaded aggs for ACDC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ACDC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:18,417 - Downloaded aggs for ACEL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ACEL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:18,857 - Downloaded aggs for ACMR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ACMR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:18,874 - Downloaded aggs for ACHR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ACHR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:19,839 - Downloaded aggs for ADSE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ADSE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:19,870 - Downloaded aggs for ACIC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ACIC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:20,641 - Downloaded aggs for ADNT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ADNT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:21,507 - Downloaded aggs for AFYA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AFYA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:21,986 - Downloaded aggs for ADEA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ADEA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:22,287 - Downloaded aggs for ADV from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ADV-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:19:22,684 - Downloaded aggs for ADPT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ADPT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:49,839 - Downloaded aggs for AGM from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AGM-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:51,037 - Downloaded aggs for AG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:51,672 - Downloaded aggs for AGL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AGL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:51,959 - Downloaded aggs for AGRO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AGRO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:51,974 - Downloaded aggs for AGM.A from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AGM.A-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:52,937 - Downloaded aggs for AGX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AGX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:54,981 - Downloaded aggs for AHCO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AHCO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:55,200 - Downloaded aggs for AHH from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AHH-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:56,686 - Downloaded aggs for AIOT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AIOT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:20:57,214 - Downloaded aggs for AIO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AIO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:22,536 - Downloaded aggs for AIV from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AIV-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:22,883 - Downloaded aggs for ALGT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ALGT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:23,666 - Downloaded aggs for AKRO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AKRO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:24,017 - Downloaded aggs for ALEC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ALEC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:24,403 - Downloaded aggs for ALEX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ALEX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:26,920 - Downloaded aggs for ALLO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ALLO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:29,348 - Downloaded aggs for ALMS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ALMS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:29,796 - Downloaded aggs for ALRS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ALRS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:30,063 - Downloaded aggs for ALX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ALX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:22:31,799 - Downloaded aggs for AMAL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMAL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:23:58,544 - Downloaded aggs for AMBC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMBC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:00,794 - Downloaded aggs for AMN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:01,360 - Downloaded aggs for AMC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:01,360 - Downloaded aggs for AMPL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMPL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:03,227 - Downloaded aggs for AMPS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMPS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:03,611 - Downloaded aggs for AMRC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMRC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:06,489 - Downloaded aggs for AMRK from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMRK-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:06,697 - Downloaded aggs for AMSC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMSC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:08,733 - Downloaded aggs for AMSF from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMSF-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:24:10,002 - Downloaded aggs for AMTB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMTB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:34,423 - Downloaded aggs for AMWD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AMWD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:35,618 - Downloaded aggs for ANGI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ANGI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:35,786 - Downloaded aggs for ANAB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ANAB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:36,344 - Downloaded aggs for ANDE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ANDE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:36,406 - Downloaded aggs for ANIP from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ANIP-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:38,237 - Downloaded aggs for ANNX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ANNX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:41,463 - Downloaded aggs for AOD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AOD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:42,628 - Downloaded aggs for AORT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AORT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:44,799 - Downloaded aggs for AOSL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AOSL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:25:46,437 - Downloaded aggs for APLD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\APLD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:06,754 - Downloaded aggs for APLT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\APLT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:08,392 - Downloaded aggs for ARCO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARCO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:09,230 - Downloaded aggs for APOG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\APOG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:09,941 - Downloaded aggs for ARCT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARCT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:10,187 - Downloaded aggs for ARDX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARDX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:12,472 - Downloaded aggs for ARI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:13,330 - Downloaded aggs for ARHS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARHS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:14,633 - Downloaded aggs for ARIS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARIS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:16,695 - Downloaded aggs for ARKO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARKO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:27:20,139 - Downloaded aggs for ARLO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARLO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:41,472 - Downloaded aggs for ARMN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARMN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:42,205 - Downloaded aggs for ARQT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARQT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:42,621 - Downloaded aggs for ARR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:43,238 - Downloaded aggs for ARRY from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARRY-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:43,488 - Downloaded aggs for ASAI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ASAI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:44,491 - Downloaded aggs for ARVN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ARVN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:46,730 - Downloaded aggs for ASGI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ASGI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:46,824 - Downloaded aggs for ASIX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ASIX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:47,106 - Downloaded aggs for ASC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ASC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:28:52,037 - Downloaded aggs for ASPN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ASPN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:01,486 - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None)': /v2/aggs/ticker/ATSG/range/1/day/2023-07-20/2023-07-20?limit=50000
# 2024-10-18 15:30:14,509 - Downloaded aggs for ASTE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ASTE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:15,824 - Downloaded aggs for ATEC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATEC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:16,342 - Downloaded aggs for ASTL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ASTL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:18,276 - Downloaded aggs for ATLC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATLC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:19,253 - Downloaded aggs for ATEN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATEN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:20,092 - Downloaded aggs for ATRO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATRO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:21,402 - Downloaded aggs for ATEX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATEX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:21,932 - Downloaded aggs for ATRC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATRC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:22,551 - Downloaded aggs for ATNI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATNI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:30:47,357 - Downloaded aggs for ATSG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATSG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:52,092 - Downloaded aggs for ATUS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATUS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:54,992 - Downloaded aggs for ATXS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ATXS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:55,060 - Downloaded aggs for AUNA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AUNA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:56,703 - Downloaded aggs for AVBP from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AVBP-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:57,163 - Downloaded aggs for AVAH from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AVAH-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:57,219 - Downloaded aggs for AVDL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AVDL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:57,434 - Downloaded aggs for AURA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AURA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:57,449 - Downloaded aggs for AUTL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AUTL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:31:58,246 - Downloaded aggs for AUPH from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AUPH-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:32:24,932 - Downloaded aggs for AVDX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AVDX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:26,350 - Downloaded aggs for AVNS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AVNS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:29,482 - Downloaded aggs for AWF from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AWF-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:31,335 - Downloaded aggs for AVO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AVO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:31,836 - Downloaded aggs for BALY from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BALY-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:32,798 - Downloaded aggs for AXL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AXL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:33,260 - Downloaded aggs for AXGN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AXGN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:33,924 - Downloaded aggs for AZTA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\AZTA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:34,159 - Downloaded aggs for BB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:33:35,403 - Downloaded aggs for BASE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BASE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:34:01,010 - Downloaded aggs for BBDC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BBDC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:34:59,330 - Downloaded aggs for BBN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BBN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:01,142 - Downloaded aggs for BBSI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BBSI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:02,683 - Downloaded aggs for BBU from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BBU-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:03,879 - Downloaded aggs for BBUC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BBUC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:03,957 - Downloaded aggs for BCAX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BCAX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:04,776 - Downloaded aggs for BCAT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BCAT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:05,438 - Downloaded aggs for BCRX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BCRX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:05,501 - Downloaded aggs for BBW from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BBW-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:09,743 - Downloaded aggs for BCSF from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BCSF-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:35:32,442 - Downloaded aggs for BCX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BCX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:29,146 - Downloaded aggs for BCYC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BCYC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:31,499 - Downloaded aggs for BDJ from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BDJ-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:34,359 - Downloaded aggs for BELFA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BELFA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:35,287 - Downloaded aggs for BDN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BDN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:36,190 - Downloaded aggs for BEAM from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BEAM-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:36,759 - Downloaded aggs for BFC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BFC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:37,315 - Downloaded aggs for BELFB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BELFB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:39,644 - Downloaded aggs for BFS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BFS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:36:42,058 - Downloaded aggs for BFST from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BFST-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:37:03,644 - Downloaded aggs for BGS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BGS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:04,138 - Downloaded aggs for BGY from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BGY-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:05,212 - Downloaded aggs for BH from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BH-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:07,096 - Downloaded aggs for BH.A from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BH.A-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:07,521 - Downloaded aggs for BHE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BHE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:09,203 - Downloaded aggs for BHRB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BHRB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:09,422 - Downloaded aggs for BHK from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BHK-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:09,924 - Downloaded aggs for BIGZ from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BIGZ-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:10,301 - Downloaded aggs for BIOA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BIOA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:15,615 - Downloaded aggs for BIT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BIT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:38:34,513 - Downloaded aggs for BITF from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BITF-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:34,505 - Downloaded aggs for BKD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BKD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:35,717 - Downloaded aggs for BJRI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BJRI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:36,270 - Downloaded aggs for BKV from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BKV-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:39,324 - Downloaded aggs for BLE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:39,606 - Downloaded aggs for BLBD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLBD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:39,685 - Downloaded aggs for BLND from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLND-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:41,038 - Downloaded aggs for BLMN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLMN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:43,388 - Downloaded aggs for BLFS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLFS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:39:46,769 - Downloaded aggs for BLTE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLTE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:40:05,344 - Downloaded aggs for BLW from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLW-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:08,153 - Downloaded aggs for BMBL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BMBL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:08,310 - Downloaded aggs for BLX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BLX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:11,724 - Downloaded aggs for BMEZ from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BMEZ-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:12,193 - Downloaded aggs for BOE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BOE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:13,377 - Downloaded aggs for BORR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BORR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:22,918 - Downloaded aggs for BRSP from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BRSP-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:37,720 - Downloaded aggs for BSIG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BSIG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:38,452 - Downloaded aggs for BME from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BME-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:42,668 - Downloaded aggs for BOW from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BOW-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:41:48,325 - Downloaded aggs for BRKL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BRKL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:42:44,120 - Downloaded aggs for BST from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BST-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:42:44,353 - Downloaded aggs for BSTZ from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BSTZ-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:42:46,769 - Downloaded aggs for BTBT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BTBT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:42:49,132 - Downloaded aggs for BTDR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BTDR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:42:50,465 - Downloaded aggs for BTT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BTT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:42:58,540 - Downloaded aggs for BTZ from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BTZ-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:43:10,600 - Downloaded aggs for BUI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BUI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:43:17,323 - Downloaded aggs for BUSE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BUSE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:43:19,589 - Downloaded aggs for BV from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BV-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:43:21,442 - Downloaded aggs for BVS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BVS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:17,968 - Downloaded aggs for BXC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BXC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:18,488 - Downloaded aggs for BWLP from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BWLP-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:19,754 - Downloaded aggs for BXMX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BXMX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:22,461 - Downloaded aggs for BZH from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BZH-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:24,340 - Downloaded aggs for BY from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\BY-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:33,708 - Downloaded aggs for CABO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CABO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:43,209 - Downloaded aggs for CAKE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CAKE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:50,447 - Downloaded aggs for CAL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CAL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:44:53,020 - Downloaded aggs for CAPL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CAPL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:45:00,891 - Downloaded aggs for CAPR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CAPR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:45:52,187 - Downloaded aggs for CASH from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CASH-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:45:54,131 - Downloaded aggs for CARS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CARS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:45:55,543 - Downloaded aggs for CASS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CASS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:45:56,525 - Downloaded aggs for CATX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CATX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:45:58,738 - Downloaded aggs for CBL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CBL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:46:06,806 - Downloaded aggs for CBLL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CBLL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:46:15,140 - Downloaded aggs for CBRL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CBRL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:46:25,989 - Downloaded aggs for CCAP from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCAP-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:46:29,560 - Downloaded aggs for CCB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:46:36,788 - Downloaded aggs for CCBG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCBG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:26,750 - Downloaded aggs for CCNE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCNE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:28,244 - Downloaded aggs for CCD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:28,259 - Downloaded aggs for CCEC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCEC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:29,719 - Downloaded aggs for CCO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:32,871 - Downloaded aggs for CCU from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CCU-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:44,160 - Downloaded aggs for CDMO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CDMO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:51,710 - Downloaded aggs for CDNA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CDNA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:47:59,940 - Downloaded aggs for CDRE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CDRE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:48:03,964 - Downloaded aggs for CECO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CECO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:48:11,762 - Downloaded aggs for CELC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CELC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:01,123 - Downloaded aggs for CERT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CERT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:02,247 - Downloaded aggs for CENTA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CENTA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:02,648 - Downloaded aggs for CEPU from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CEPU-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:04,755 - Downloaded aggs for CET from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CET-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:05,085 - Downloaded aggs for CEVA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CEVA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:16,133 - Downloaded aggs for CFB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CFB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:23,189 - Downloaded aggs for CFFN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CFFN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:32,865 - Downloaded aggs for CGAU from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CGAU-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:36,262 - Downloaded aggs for CGBD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CGBD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:49:44,766 - Downloaded aggs for CGEM from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CGEM-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:50:32,196 - Downloaded aggs for CGNT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CGNT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:50:34,970 - Downloaded aggs for CHEF from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CHEF-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:50:35,713 - Downloaded aggs for CHCO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CHCO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:50:37,267 - Downloaded aggs for CHI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CHI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 15:50:37,797 - Downloaded aggs for CHPT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\CHPT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# ...
# 2024-10-18 16:54:24,142 - Downloaded aggs for LNN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LNN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:02,339 - Downloaded aggs for LOMA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LOMA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:05,292 - Downloaded aggs for LPG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LPG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:17,686 - Downloaded aggs for LPRO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LPRO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:25,704 - Downloaded aggs for LQDA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LQDA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:37,448 - Downloaded aggs for LRMR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LRMR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:39,446 - Downloaded aggs for LQDT from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LQDT-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:39,919 - Downloaded aggs for LTC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LTC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:45,816 - Downloaded aggs for LUNR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LUNR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:49,168 - Downloaded aggs for LVRO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LVRO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:55:54,704 - Downloaded aggs for LVWR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LVWR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:56:35,812 - Downloaded aggs for LXRX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LXRX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:56:36,332 - Downloaded aggs for LXU from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LXU-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:56:59,141 - Downloaded aggs for LZB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LZB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:57:10,962 - Downloaded aggs for LZM from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LZM-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:57:12,878 - Downloaded aggs for MAG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MAG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:57:21,815 - Downloaded aggs for MAX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MAX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:57:21,974 - Downloaded aggs for LZ from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\LZ-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:57:25,338 - Downloaded aggs for MBIN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MBIN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:57:41,746 - Downloaded aggs for MATW from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MATW-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:01,732 - Downloaded aggs for MBWM from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MBWM-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:12,666 - Downloaded aggs for MCB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MCB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:24,314 - Downloaded aggs for MBX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MBX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:29,023 - Downloaded aggs for MCBS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MCBS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:41,794 - Downloaded aggs for MCW from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MCW-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:45,570 - Downloaded aggs for MCRI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MCRI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:50,976 - Downloaded aggs for MD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:52,989 - Downloaded aggs for MDXG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MDXG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:58:58,937 - Downloaded aggs for MEG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MEG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:59:14,576 - Downloaded aggs for MEGI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MEGI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:59:31,633 - Downloaded aggs for MESO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MESO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:59:40,319 - Downloaded aggs for METC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\METC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 16:59:54,486 - Downloaded aggs for METCB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\METCB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:00:04,743 - Downloaded aggs for MFA from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MFA-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:00:14,095 - Downloaded aggs for MFIC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MFIC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:00:15,043 - Downloaded aggs for MGNI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MGNI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:00:20,836 - Downloaded aggs for MHD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MHD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:00:33,340 - Downloaded aggs for MIRM from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MIRM-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:00:33,755 - Downloaded aggs for ML from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\ML-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:00:47,380 - Downloaded aggs for MLAB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MLAB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:01:05,006 - Downloaded aggs for MLKN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MLKN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:01:12,674 - Downloaded aggs for MLNK from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MLNK-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:01:27,425 - Downloaded aggs for MLR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MLR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:01:44,645 - Downloaded aggs for MLYS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MLYS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:01:50,127 - Downloaded aggs for MMI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MMI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:01:51,453 - Downloaded aggs for MMU from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MMU-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:01:54,369 - Downloaded aggs for MNKD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MNKD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:02:06,890 - Downloaded aggs for MNMD from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MNMD-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:02:06,961 - Downloaded aggs for MNR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MNR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:02:18,871 - Downloaded aggs for MNRO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MNRO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:02:42,460 - Downloaded aggs for MNTK from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MNTK-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:02:49,524 - Downloaded aggs for MODG from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MODG-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:04,792 - Downloaded aggs for MOMO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MOMO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:17,417 - Downloaded aggs for MPB from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MPB-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:24,585 - Downloaded aggs for MQY from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MQY-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:27,169 - Downloaded aggs for MRC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MRC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:29,758 - Downloaded aggs for MRCY from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MRCY-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:41,756 - Downloaded aggs for MRNO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MRNO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:43,895 - Downloaded aggs for MREO from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MREO-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:03:52,189 - Downloaded aggs for MRTN from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MRTN-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:04:16,872 - Downloaded aggs for MRVI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MRVI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:04:23,929 - Downloaded aggs for MRX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MRX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:04:37,791 - Downloaded aggs for MSBI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MSBI-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:04:53,927 - Downloaded aggs for MSC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MSC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:00,636 - Downloaded aggs for MSDL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MSDL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:01,197 - Downloaded aggs for MSEX from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MSEX-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:02,981 - Downloaded aggs for MSGE from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MSGE-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:16,801 - Downloaded aggs for MTTR from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MTTR-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:18,558 - Downloaded aggs for MTAL from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MTAL-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:25,879 - Downloaded aggs for MTUS from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MTUS-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:51,854 - Downloaded aggs for MUC from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MUC-aggs-2022-01-01_to_2024-09-30.pickle.lz4
# 2024-10-18 17:05:57,535 - Downloaded aggs for MUI from 2022-01-01 to 2024-09-30 and saved to C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\rawAggs\MUI-aggs-2022-01-01_to_2024-09-30.pickle.lz4

# %%
# THIS IS TO FETCH DATA FROM THE API

# Define the API details
# client = RESTClient(api_key="<API_KEY>")

# Set up logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(message)s")


def signal_handler(sig, frame):
    print("You pressed Ctrl+C!")
    sys.exit(0)


signal.signal(signal.SIGINT, signal_handler)


def get_aggs_for_symbol_and_date(symbol_date_pair):
    """Retrieve aggs for a given symbol and date"""
    symbol, date = symbol_date_pair
    aggs = []
    client = RESTClient(api_key="PfZz8S38d1PO4heiApoM7SGLFohMi3KE")  # Uses POLYGON_API_KEY environment variable

    for a in client.list_aggs(
        symbol,
        1,
        "day",
        date,
        date,
        limit=50000,
    ):
        aggs.append(a)

    # print(len(aggs))

    filename = f"{symbol}-aggs-{date}.pickle.lz4"
    with open(filename, "wb") as file:
        try:
            compressed_data = lz4.frame.compress(pickle.dumps(aggs))
            file.write(compressed_data)
        except TypeError as e:
            print(f"Serialization Error: {e}")

    logging.info(f"Downloaded aggs for {date} and saved to {filename}")


def weekdays_between(start_date, end_date):
    """Generate all weekdays between start_date and end_date"""
    day = start_date
    while day <= end_date:
        if day.weekday() < 5:  # 0-4 denotes Monday to Friday
            yield day
        day += datetime.timedelta(days=1)


def main():
    start_date = datetime.date(2023, 8, 1)
    end_date = datetime.date(2023, 8, 31)

    symbols = ["AAPL"]  # The array of symbols you want

    dates = list(weekdays_between(start_date, end_date))

    # Generate a list of (symbol, date) pairs
    symbol_date_pairs = [(symbol, date) for symbol in symbols for date in dates]

    # Use ThreadPoolExecutor to download data in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=50) as executor:
        executor.map(get_aggs_for_symbol_and_date, symbol_date_pairs)


if __name__ == "__main__":
    main()
# Out:
# 2024-10-18 14:43:14,837 - Downloaded aggs for 2023-08-17 and saved to AAPL-aggs-2023-08-17.pickle.lz4
# 2024-10-18 14:43:14,840 - Downloaded aggs for 2023-08-18 and saved to AAPL-aggs-2023-08-18.pickle.lz4
# 2024-10-18 14:43:14,841 - Downloaded aggs for 2023-08-24 and saved to AAPL-aggs-2023-08-24.pickle.lz4
# 2024-10-18 14:43:14,842 - Downloaded aggs for 2023-08-07 and saved to AAPL-aggs-2023-08-07.pickle.lz4
# 2024-10-18 14:43:14,850 - Downloaded aggs for 2023-08-16 and saved to AAPL-aggs-2023-08-16.pickle.lz4
# 2024-10-18 14:43:14,857 - Downloaded aggs for 2023-08-25 and saved to AAPL-aggs-2023-08-25.pickle.lz4
# 2024-10-18 14:43:14,884 - Downloaded aggs for 2023-08-22 and saved to AAPL-aggs-2023-08-22.pickle.lz4
# 2024-10-18 14:43:14,890 - Downloaded aggs for 2023-08-15 and saved to AAPL-aggs-2023-08-15.pickle.lz4
# 2024-10-18 14:43:14,890 - Downloaded aggs for 2023-08-11 and saved to AAPL-aggs-2023-08-11.pickle.lz4
# 2024-10-18 14:43:14,891 - Downloaded aggs for 2023-08-14 and saved to AAPL-aggs-2023-08-14.pickle.lz4
# 2024-10-18 14:43:14,891 - Downloaded aggs for 2023-08-02 and saved to AAPL-aggs-2023-08-02.pickle.lz4
# 2024-10-18 14:43:14,891 - Downloaded aggs for 2023-08-10 and saved to AAPL-aggs-2023-08-10.pickle.lz4
# 2024-10-18 14:43:14,891 - Downloaded aggs for 2023-08-28 and saved to AAPL-aggs-2023-08-28.pickle.lz4
# 2024-10-18 14:43:14,891 - Downloaded aggs for 2023-08-21 and saved to AAPL-aggs-2023-08-21.pickle.lz4
# 2024-10-18 14:43:14,892 - Downloaded aggs for 2023-08-31 and saved to AAPL-aggs-2023-08-31.pickle.lz4
# 2024-10-18 14:43:14,892 - Downloaded aggs for 2023-08-09 and saved to AAPL-aggs-2023-08-09.pickle.lz4
# 2024-10-18 14:43:14,892 - Downloaded aggs for 2023-08-04 and saved to AAPL-aggs-2023-08-04.pickle.lz4
# 2024-10-18 14:43:14,893 - Downloaded aggs for 2023-08-08 and saved to AAPL-aggs-2023-08-08.pickle.lz4
# 2024-10-18 14:43:14,893 - Downloaded aggs for 2023-08-30 and saved to AAPL-aggs-2023-08-30.pickle.lz4
# 2024-10-18 14:43:14,897 - Downloaded aggs for 2023-08-23 and saved to AAPL-aggs-2023-08-23.pickle.lz4
# 2024-10-18 14:43:14,897 - Downloaded aggs for 2023-08-29 and saved to AAPL-aggs-2023-08-29.pickle.lz4
# 2024-10-18 14:43:14,899 - Downloaded aggs for 2023-08-01 and saved to AAPL-aggs-2023-08-01.pickle.lz4
# 2024-10-18 14:43:15,013 - Downloaded aggs for 2023-08-03 and saved to AAPL-aggs-2023-08-03.pickle.lz4

# %%
# THIS IS TO READ THE FETCHED LZ4 FILES FROM FOLDER PATH

def read_trades_for_date(symbol, date):
    """Reads trades for a given symbol and date, then prints them."""

    # Construct the filename, similar to your writer script
    filename = f"{symbol}-aggs-{date}.pickle.lz4"

    try:
        with open(filename, "rb") as file:
            compressed_data = file.read()
            trades = pickle.loads(lz4.frame.decompress(compressed_data))
            print(trades)
            return trades
    except FileNotFoundError:
        print(f"No file found for {date}")
    except Exception as e:
        print(f"An error occurred: {e}")


def main():
    start_date = datetime.date(2023, 8, 1)
    end_date = datetime.date(2023, 8, 31)
    symbol = "AAPL"

    # Loop through each weekday between the start and end dates and read the trades
    day = start_date
    while day <= end_date:
        if day.weekday() < 5:  # 0-4 denotes Monday to Friday
            read_trades_for_date(symbol, day)
        day += datetime.timedelta(days=1)


if __name__ == "__main__":
    main()
# Out:
# [Agg(open=196.235, high=196.73, low=195.28, close=195.605, volume=35281426.0, vwap=195.8486, timestamp=1690862400000, transactions=477616, otc=None)]
# [Agg(open=195.04, high=195.18, low=191.8507, close=192.58, volume=50388811.0, vwap=192.9395, timestamp=1690948800000, transactions=620582, otc=None)]
# [Agg(open=191.57, high=192.37, low=190.69, close=191.17, volume=62243282.0, vwap=191.1312, timestamp=1691035200000, transactions=754703, otc=None)]
# [Agg(open=185.52, high=187.38, low=181.92, close=181.99, volume=115956841.0, vwap=184.279, timestamp=1691121600000, transactions=1336765, otc=None)]
# [Agg(open=182.13, high=183.13, low=177.35, close=178.85, volume=97105069.0, vwap=179.0119, timestamp=1691380800000, transactions=1159281, otc=None)]
# [Agg(open=179.69, high=180.27, low=177.58, close=179.8, volume=67769003.0, vwap=178.9854, timestamp=1691467200000, transactions=709019, otc=None)]
# [Agg(open=180.87, high=180.93, low=177.01, close=178.19, volume=60303492.0, vwap=178.4887, timestamp=1691553600000, transactions=666112, otc=None)]
# [Agg(open=179.48, high=180.75, low=177.6, close=177.97, volume=54686851.0, vwap=178.7951, timestamp=1691640000000, transactions=652995, otc=None)]
# [Agg(open=177.32, high=178.62, low=176.55, close=177.79, volume=51036672.0, vwap=177.8056, timestamp=1691726400000, transactions=586481, otc=None)]
# [Agg(open=177.97, high=179.69, low=177.305, close=179.46, volume=43675627.0, vwap=178.9475, timestamp=1691985600000, transactions=564982, otc=None)]
# [Agg(open=178.88, high=179.48, low=177.05, close=177.45, volume=43574863.0, vwap=177.9886, timestamp=1692072000000, transactions=510071, otc=None)]
# [Agg(open=177.13, high=178.54, low=176.5, close=176.57, volume=45712957.0, vwap=177.4133, timestamp=1692158400000, transactions=526074, otc=None)]
# [Agg(open=177.14, high=177.5054, low=173.48, close=174, volume=66054482.0, vwap=174.5857, timestamp=1692244800000, transactions=673083, otc=None)]
# [Agg(open=172.3, high=175.1, low=171.96, close=174.49, volume=60171878.0, vwap=173.8904, timestamp=1692331200000, transactions=596474, otc=None)]
# [Agg(open=175.07, high=176.13, low=173.735, close=175.84, volume=46161959.0, vwap=175.2221, timestamp=1692590400000, transactions=559658, otc=None)]
# [Agg(open=177.06, high=177.68, low=176.25, close=177.23, volume=42057245.0, vwap=177.0098, timestamp=1692676800000, transactions=501508, otc=None)]
# [Agg(open=178.52, high=181.55, low=178.325, close=181.12, volume=52722752.0, vwap=180.6482, timestamp=1692763200000, transactions=587165, otc=None)]
# [Agg(open=180.674, high=181.104, low=176.01, close=176.38, volume=54912798.0, vwap=177.7035, timestamp=1692849600000, transactions=610377, otc=None)]
# [Agg(open=177.38, high=179.15, low=175.82, close=178.61, volume=51439994.0, vwap=177.9075, timestamp=1692936000000, transactions=554789, otc=None)]
# [Agg(open=180.09, high=180.59, low=178.545, close=180.19, volume=43803238.0, vwap=179.6595, timestamp=1693195200000, transactions=532485, otc=None)]
# [Agg(open=179.695, high=184.9, low=179.5, close=184.12, volume=52953948.0, vwap=183.28, timestamp=1693281600000, transactions=576465, otc=None)]
# [Agg(open=184.94, high=187.85, low=184.74, close=187.65, volume=60803988.0, vwap=186.93, timestamp=1693368000000, transactions=636448, otc=None)]
# [Agg(open=187.84, high=189.12, low=187.48, close=187.87, volume=60794467.0, vwap=188.1489, timestamp=1693454400000, transactions=554869, otc=None)]

# %%
# Define API key and base URL
api_key = "PfZz8S38d1PO4heiApoM7SGLFohMi3KE"
base_url_open_close = "https://api.polygon.io/v1/open-close"
base_url_financials = "https://api.polygon.io/vX/reference/financials"

# Read the existing CSV file to determine the last date
existing_file_path = r"C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\ntnx_data_raw.csv"
existing_data = pd.read_csv(existing_file_path, delimiter=';', header=0)

# Ensure the 'Date' column is in datetime format and get the last date
existing_data['Date'] = pd.to_datetime(existing_data['Date'])

# Define ticker and date range
ticker = "NTNX"
start_date = "2022-10-18"
end_date = "2022-12-31"

# Convert date strings to datetime objects
start = datetime.strptime(start_date, "%Y-%m-%d")
end = datetime.strptime(end_date, "%Y-%m-%d")

# Initialize an empty list to hold all stock data
all_stock_data = []

# %%
# Initialize API call counter
# api_call_count = 0
# # Function to handle API call rate limit
# def check_rate_limit():
#     global api_call_count
#     api_call_count += 1
#     if api_call_count == 5:
#         print("Pausing for 1 minute to respect API rate limit...")
#         time.sleep(60)  # Pause for 1 minute
#         api_call_count = 0

# %%
# Function to fetch open/close data for a specific ticker and date
def fetch_stock_data(ticker, date):
    url = f"{base_url_open_close}/{ticker}/{date}"
    headers = {"Authorization": f"Bearer {api_key}"}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        if data.get("status") == "OK":
            stock_data = {
                "Symbol": data.get("symbol"),
                "Date": data.get("from"),
                "Close": data.get("close"),
                "Open": data.get("open"),
                "High": data.get("high"),
                "Low": data.get("low"),
                "Volume": data.get("volume")
            }
            return stock_data
        else:
            print(f"No trading data for {ticker} on {date}.")
            return None
    else:
        print(f"Failed to fetch data for {ticker} on {date}: {response.status_code}")
        return None

# %%
# Function to fetch financial report filing dates
def fetch_filing_dates(ticker):
    filing_dates = set()
    url = f"{base_url_financials}?ticker={ticker}&apiKey={api_key}"
    
    while url:
        response = requests.get(url)
        # check_rate_limit()  # Check and handle API rate limit
        
        if response.status_code == 200:
            data = response.json()
            for item in data.get('results', []):
                filing_date = item.get('filing_date')
                if filing_date:
                    filing_dates.add(filing_date)  # Collect filing dates
                    
            url = data.get('next_url')  # Check if there's a next page to fetch
        else:
            print(f"Failed to fetch financial data for {ticker}: {response.status_code}")
            url = None  # Stop the loop if there's an error

    return filing_dates


# Fetch financial report filing dates
filing_dates = fetch_filing_dates(ticker)

# %%
# Loop over each date in the range
current_date = start
api_call_count = 0

while current_date <= end:
    date_str = current_date.strftime("%Y-%m-%d")
    
    # Fetch stock data for the current date
    stock_data = fetch_stock_data(ticker, date_str)
    check_rate_limit()
    
    if stock_data:
        # Check if a financial report was released on this date
        stock_data["financialRelease"] = 1 if date_str in filing_dates else 0
        
        all_stock_data.append(stock_data)

    # Increment API call count
    api_call_count += 1

    # After every 5 API calls, pause for 1 minute to respect the API limit
    # if api_call_count == 5:
    #     print("Pausing for 1 minute to respect API rate limit...")
    #     time.sleep(60)
    #     api_call_count = 0

    # Move to the next date
    current_date += timedelta(days=1)

# %%
# Create a DataFrame from the collected data
df = pd.DataFrame(all_stock_data)

# %%
# Define the output path for the CSV file
# file_name = '_data'
# output_path = r"C:\Users\SamuliMustonen\Documents\Ready Solutions\Docs\StockTrading\Data\{file_name}.csv"

# Append the DataFrame to the existing CSV file, avoiding duplicates
if not df.empty:
    df.to_csv(existing_file_path, mode='a', index=False, header=False, sep=';')

print(f"Data has been appended to {existing_file_path}")
